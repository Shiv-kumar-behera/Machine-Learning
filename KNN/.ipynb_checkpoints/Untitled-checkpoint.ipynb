# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Social_Network_Ads.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
X=data.iloc[:,2:4].values

# %%
X.shape
# Out:
# (400, 2)

# %%
Y=data.iloc[:,-1].values

# %%
Y.shape
# Out:
# (400,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
X_train.shape
# Out:
# (320, 2)

# %%
X_test.shape
# Out:
# (80, 2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_train
# Out:
# array([[-0.25488776,  0.28700663],
#        [ 0.03886044, -0.24816922],
#        [ 0.72427291, -1.4077169 ],
#        [-1.0382163 , -0.45629316],
#        [-0.25488776,  0.22754265],
#        [-0.25488776, -0.48602515],
#        [-0.05905563,  0.13834667],
#        [-1.13613237, -1.16986097],
#        [ 0.33260864, -0.27790121],
#        [ 1.40968538,  2.04119415],
#        [-0.05905563,  0.22754265],
#        [-0.94030023, -0.3076332 ],
#        [ 2.19301392, -0.81307706],
#        [-0.1569717 ,  2.2195861 ],
#        [ 1.99718179, -0.93200503],
#        [-0.94030023,  0.52486257],
#        [-1.42988057, -1.46718089],
#        [-1.42988057,  0.37620261],
#        [-0.25488776,  2.30878208],
#        [-1.72362877, -0.99146902],
#        [-1.0382163 ,  0.7924505 ],
#        [-0.4507199 , -1.22932495],
#        [-0.25488776, -0.57522113],
#        [ 0.82218898, -1.37798491],
#        [ 1.01802111,  1.92226619],
#        [ 0.43052471, -0.45629316],
#        [ 0.13677651, -0.3076332 ],
#        [ 1.70343358, -0.90227304],
#        [-0.7444681 , -1.55637686],
#        [ 0.92010505, -0.78334507],
#        [ 1.99718179, -1.37798491],
#        [ 0.33260864, -0.18870524],
#        [-0.4507199 , -0.84280906],
#        [-1.52779664, -0.42656117],
#        [ 0.82218898,  0.28700663],
#        [ 0.13677651, -0.24816922],
#        [ 0.23469257,  0.25727464],
#        [ 0.82218898, -1.11039698],
#        [ 0.03886044,  0.0491507 ],
#        [ 0.52844078,  1.77360623],
#        [ 1.50760145,  2.18985411],
#        [ 0.13677651,  0.7924505 ],
#        [-1.91946091,  0.37620261],
#        [-0.1569717 , -0.45629316],
#        [-0.64655203, -0.09950926],
#        [ 0.13677651,  0.10861468],
#        [-1.13613237, -1.55637686],
#        [-1.23404844,  0.31673863],
#        [ 1.50760145, -1.050933  ],
#        [ 1.40968538,  0.61405854],
#        [-0.25488776, -0.93200503],
#        [-1.3319645 , -1.37798491],
#        [-0.05905563, -0.42656117],
#        [-1.3319645 , -0.42656117],
#        [ 0.92010505,  1.06003842],
#        [ 2.09509785,  0.4059346 ],
#        [ 1.01802111,  0.61405854],
#        [ 1.11593718,  0.55459456],
#        [-1.13613237, -1.61584084],
#        [ 0.92010505,  1.29789436],
#        [-0.25488776, -0.36709719],
#        [-1.0382163 ,  0.55459456],
#        [ 0.43052471,  0.16807867],
#        [-0.25488776,  0.07888269],
#        [-0.1569717 ,  0.88164647],
#        [ 1.21385325, -1.46718089],
#        [-0.94030023, -0.3076332 ],
#        [-0.05905563,  2.27905009],
#        [ 2.19301392, -1.050933  ],
#        [-0.4507199 , -0.01031328],
#        [ 1.60551752, -1.28878893],
#        [ 1.50760145,  1.03030643],
#        [ 1.21385325,  0.55459456],
#        [-0.7444681 ,  1.95199818],
#        [ 1.11593718, -0.90227304],
#        [-0.1569717 ,  1.65467826],
#        [ 0.03886044,  1.26816236],
#        [ 1.01802111, -1.08066499],
#        [ 0.82218898,  0.7924505 ],
#        [-0.25488776,  1.1492344 ],
#        [ 1.70343358,  1.65467826],
#        [-0.25488776, -0.3076332 ],
#        [-0.7444681 ,  0.52486257],
#        [ 0.43052471,  0.31673863],
#        [-0.35280383, -0.78334507],
#        [ 0.82218898,  1.41682232],
#        [-0.35280383,  1.35735834],
#        [-0.54863597,  1.41682232],
#        [-0.1569717 , -1.08066499],
#        [ 1.11593718,  2.13039013],
#        [-1.42988057, -1.22932495],
#        [-0.25488776, -0.12924125],
#        [-0.1569717 ,  1.44655432],
#        [-0.1569717 , -0.18870524],
#        [-0.84238417, -0.24816922],
#        [ 0.33260864,  0.07888269],
#        [ 0.23469257,  1.11950241],
#        [-0.7444681 ,  0.28700663],
#        [-0.25488776,  0.10861468],
#        [-1.72362877,  0.49513058],
#        [-1.0382163 ,  2.01146216],
#        [-1.42988057, -0.18870524],
#        [-1.62571271,  0.55459456],
#        [ 0.82218898,  0.13834667],
#        [ 0.33260864, -0.51575715],
#        [ 1.89926572,  1.56548228],
#        [ 0.72427291,  1.83307021],
#        [-1.23404844,  0.28700663],
#        [ 0.43052471,  0.10861468],
#        [-0.84238417,  0.4059346 ],
#        [-0.05905563, -0.21843723],
#        [-1.52779664,  0.34647062],
#        [ 0.03886044, -0.54548914],
#        [-0.54863597, -1.52664487],
#        [-0.35280383,  0.07888269],
#        [-1.62571271, -0.04004528],
#        [-1.42988057, -0.09950926],
#        [ 0.43052471, -0.48602515],
#        [ 0.33260864,  0.28700663],
#        [-0.54863597,  1.41682232],
#        [-0.25488776,  0.64379054],
#        [ 0.23469257, -0.36709719],
#        [ 0.43052471, -0.12924125],
#        [-0.05905563,  0.70325452],
#        [-0.64655203, -1.050933  ],
#        [ 0.33260864, -0.3076332 ],
#        [-0.64655203,  0.19781066],
#        [ 0.72427291, -1.4077169 ],
#        [ 1.01802111,  2.04119415],
#        [-1.0382163 ,  0.61405854],
#        [ 1.01802111, -1.19959296],
#        [ 1.99718179,  0.94111045],
#        [-0.25488776, -0.27790121],
#        [-0.7444681 , -0.60495312],
#        [-0.25488776, -1.4077169 ],
#        [-0.05905563,  0.16807867],
#        [-1.72362877, -0.60495312],
#        [-0.7444681 ,  0.31673863],
#        [-1.82154484,  0.19781066],
#        [ 0.23469257,  0.16807867],
#        [-0.25488776, -0.90227304],
#        [ 0.43052471,  1.03030643],
#        [ 0.03886044, -0.24816922],
#        [ 0.82218898, -1.22932495],
#        [-0.05905563, -0.36709719],
#        [-0.94030023, -1.11039698],
#        [-0.05905563, -1.08066499],
#        [ 0.33260864, -0.51575715],
#        [-1.72362877,  0.13834667],
#        [-0.05905563,  2.01146216],
#        [-0.4507199 , -1.14012897],
#        [ 0.43052471, -0.45629316],
#        [-1.13613237, -1.02120101],
#        [-0.54863597,  0.49513058],
#        [-0.4507199 ,  2.36824606],
#        [-1.62571271,  0.07888269],
#        [ 0.03886044, -0.3076332 ],
#        [ 1.11593718, -1.22932495],
#        [ 1.50760145,  0.07888269],
#        [-0.94030023,  0.43566659],
#        [-0.94030023, -0.75361308],
#        [-0.05905563,  0.07888269],
#        [-1.91946091, -0.75361308],
#        [ 0.03886044,  0.0491507 ],
#        [ 0.43052471,  0.28700663],
#        [ 1.99718179,  0.7627185 ],
#        [ 2.09509785, -0.81307706],
#        [ 1.70343358,  1.80333822],
#        [-1.52779664, -1.52664487],
#        [-0.25488776, -0.33736519],
#        [-1.13613237, -1.11039698],
#        [-0.25488776, -1.37798491],
#        [ 0.52844078,  1.26816236],
#        [-0.84238417, -0.66441711],
#        [-0.25488776,  0.16807867],
#        [ 0.92010505, -1.050933  ],
#        [-1.13613237,  0.07888269],
#        [-0.7444681 ,  1.11950241],
#        [-0.84238417, -1.22932495],
#        [ 0.03886044,  0.31673863],
#        [-1.0382163 , -1.46718089],
#        [ 0.92010505, -1.46718089],
#        [ 0.72427291,  0.28700663],
#        [-1.3319645 , -0.42656117],
#        [-1.0382163 , -0.33736519],
#        [ 0.92010505,  1.11950241],
#        [-0.05905563,  2.2195861 ],
#        [-0.4507199 , -0.54548914],
#        [ 0.23469257, -0.12924125],
#        [-1.0382163 ,  0.58432655],
#        [-0.25488776, -0.66441711],
#        [ 1.11593718, -0.99146902],
#        [-1.13613237,  1.44655432],
#        [-0.05905563,  0.01941871],
#        [ 1.40968538,  2.39797805],
#        [-1.0382163 , -1.14012897],
#        [ 1.89926572, -1.28878893],
#        [ 0.92010505, -1.16986097],
#        [-0.84238417,  2.33851407],
#        [ 0.92010505, -0.54548914],
#        [ 0.82218898, -0.84280906],
#        [ 1.01802111,  1.83307021],
#        [-0.64655203, -0.04004528],
#        [ 0.62635684,  2.07092614],
#        [ 1.11593718,  0.13834667],
#        [ 0.33260864,  0.07888269],
#        [-1.72362877,  0.37620261],
#        [ 0.13677651,  0.0491507 ],
#        [-0.64655203, -1.61584084],
#        [-1.82154484, -1.31852093],
#        [-1.13613237, -0.51575715],
#        [-0.05905563, -0.48602515],
#        [-0.54863597,  1.95199818],
#        [-0.05905563,  0.31673863],
#        [ 1.50760145,  0.37620261],
#        [ 1.60551752,  1.03030643],
#        [-0.94030023,  0.58432655],
#        [ 1.11593718,  0.58432655],
#        [ 2.19301392,  0.4059346 ],
#        [ 1.21385325, -0.75361308],
#        [ 1.31176932,  2.27905009],
#        [ 0.13677651,  0.22754265],
#        [-1.3319645 , -0.33736519],
#        [-0.1569717 , -0.51575715],
#        [-1.13613237,  0.31673863],
#        [ 1.01802111,  1.47628631],
#        [-0.05905563, -0.51575715],
#        [-1.52779664, -0.18870524],
#        [ 2.19301392, -0.81307706],
#        [ 1.01802111, -1.08066499]])

# %%
X_test=scaler.transform(X_test)

# %%
np.sqrt(X_train.shape[0])
# Out:
# np.float64(17.88854381999832)

# %%
k = 17

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=k)

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=17)

# %%
y_pred = knn.predict(X_test)

# %%
y_pred.shape
# Out:
# (80,)

# %%
Y_test.shape
# Out:
# (80,)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test, y_pred)
# Out:
# 0.875

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test, y_pred)
# Out:
# array([[44,  6],
#        [ 4, 26]])

# %%
accuracy = []
for i in range(1, 26):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, Y_train)
    accuracy.append(accuracy_score(Y_test, knn.predict(X_test)))

# %%
len(accuracy)
# Out:
# 25

# %%
plt.plot(range(1,26), accuracy)

# %%
knn=KNeighborsClassifier(n_neighbors=25)
knn.fit(X_train, Y_train)
y_pred = knn.predict(X_test)
accuracy_score(Y_test, y_pred)
# Out:
# 0.8875

# %%
def predict_output():
    age=int(input("Enter age"))
    salary=int(input("Enter salary"))

    x_new = np.array([[age],[salary]]).reshape(1,2)
    x_new=scaler.transform(x_new)
    if (knn.predict(x_new)[0] == 0):
        return "Will not purchase"
    else:
        return "Will purchase"

# %%
predict_output()
# Out:
# Enter age 26
# Enter salary 45000
# 'Will not purchase'
