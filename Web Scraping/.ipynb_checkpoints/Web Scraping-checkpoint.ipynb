# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Language": "en-US,en;q=0.9,en-IN;q=0.8,or;q=0.7",
    "Cache-Control": "max-age=0",
    "Connection": "keep-alive",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36 Edg/138.0.0.0",
    "Upgrade-Insecure-Requests": "1",
    "sec-ch-ua": "\"Not)A;Brand\";v=\"8\", \"Chromium\";v=\"138\", \"Microsoft Edge\";v=\"138\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
}

cookies = {
    "_t_ds": "fdfa264c1754641843-21fdfa264c-0fdfa264c",
    "showChatbot": "y",
    "_gcl_au": "1.1.901631763.1754641847",
    "_ga": "GA1.1.634575060.1754641847",
    "_fbp": "fb.1.1754641847848.47649764746184074",
    "ak_bmsc": "08425C6651857CD43AEB7229470E87A8~000000000000000000000000000000~...",
    "_ga_HV7DJVVBCW": "GS2.1.s1754749251$o6$g0$t1754749251$j60$l0$h0",
    "bm_sv": "06311C5024A793FF78F4F0915324DD04~",
}

# %%
data_set = pd.DataFrame()
for j in range(1, 504):
    url = "https://www.ambitionbox.com/list-of-companies?campaign=homepage_companies_widget&page={}".format(j)
    response = requests.get(url, headers=headers, cookies=cookies)
    soup = BeautifulSoup(response.text, 'lxml')
    company = soup.find_all("div", class_ = "companyCardWrapper")
    name = []
    rating = []
    reviews = []
    category = []
    hq = []
    no_of_branches = []
    salary = []
    no_of_interviews = []
    jobs = []
    for i in company:
        name.append(i.find("h2").text.strip())
        try:
            rating.append(i.find("div", class_ = "rating_text").text.strip())
        except:
            rating.append(np.nan)
        try:
            reviews.append(i.find("span", class_ = "companyCardWrapper__companyRatingCount").text.strip().split(")")[0][1:])
        except:
            reviews.append(np.nan)
        x = i.find("span", class_ = "companyCardWrapper__interLinking").text.strip()
        if("|" in x):
            x = x.split("|")
            try:
                category.append(x[0])
            except:
                category.append(np.nan)
            try:
                hq.append(x[1].split("+")[0].strip())
            except:
                hq.append(np.nan)
            try:
                no_of_branches.append(x[1].split("+")[1].split(" ")[0])
            except:
                no_of_branches.append(np.nan)
        else:
            category.append(np.nan)
            try:
                hq.append(x.split("+")[0].strip())
            except:
                hq.append(np.nan)
            try:
                no_of_branches.append(x.split("+")[1].split(" ")[0])
            except:
                no_of_branches.append(np.nan)
        try:
            salary.append(i.find_all("span", class_ = "companyCardWrapper__ActionCount")[1].text.strip())
        except:
            salary.append(np.nan)
        try:
            no_of_interviews.append(i.find_all("span", class_ = "companyCardWrapper__ActionCount")[2].text.strip())
        except:
            no_of_interviews.append(np.nan)
        try:
            jobs.append(i.find_all("span", class_ = "companyCardWrapper__ActionCount")[3].text.strip())
        except:
            jobs.append(np.nan)
    
    d = {"name": name, "rating": rating, "reviews": reviews, "category": category, "hq": hq, "no_of_branches": no_of_branches, "salary": salary, "no_of_interviews": no_of_interviews, "jobs": jobs}
    df = pd.DataFrame(d)
    data_set = pd.concat([data_set, df], ignore_index=True)
data_set
# Out:
#                                         name rating reviews  \
# 0                                        TCS    3.5      1L
# 1                                  Accenture    3.7     65k
# 2                                      Wipro    3.7   58.5k
# 3                                  Cognizant    3.7   55.6k
# 4                                  Capgemini    3.7   47.3k
# ...                                      ...    ...     ...
# 9995                             Gurit India    4.0      96
# 9996  Kuwait Integrated Petroleum Industries    4.2      96
# 9997                          Civet Projects    4.2      97
# 9998                Cryptograph Technologies    3.8      96
# 9999                      Pacifica Companies    3.6      96
#
#                        category                        hq no_of_branches  \
# 0     IT Services & Consulting      Bangalore / Bengaluru            412
# 1     IT Services & Consulting      Bangalore / Bengaluru            229
# 2     IT Services & Consulting      Bangalore / Bengaluru            358
# 3     IT Services & Consulting   Hyderabad / Secunderabad            213
# 4     IT Services & Consulting      Bangalore / Bengaluru            175
# ...                         ...                       ...            ...
# 9995                  Internet                    Chennai              8
# 9996                        NaN                    Mumbai              8
# 9997                        NaN  Hyderabad / Secunderabad             14
# 9998  IT Services & Consulting      Bangalore / Bengaluru             11
# 9999               Real Estate                  Ahmedabad              7
#
#      salary no_of_interviews   jobs
# 0      9.4L            11.2k    115
# 1      6.2L             8.8k  19.8k
# 2      4.7L             6.2k   7.1k
# 3        6L               6k    295
# 4      4.7L             5.1k   1.8k
# ...     ...              ...    ...
# 9995    435               12      1
# 9996    469               16     --
# 9997    279                5      6
# 9998    207                3     --
# 9999    429                3      4
#
# [10000 rows x 9 columns]

# %%
data_set.shape
# Out:
# (10000, 9)

# %%
data_set.isna().sum()
# Out:
# name                  0
# rating                0
# reviews               0
# category            648
# hq                    0
# no_of_branches       36
# salary                0
# no_of_interviews      0
# jobs                  0
# dtype: int64

# %%
data_set[data_set.isna().any(axis=1)]
# Out:
#                                         name rating reviews  \
# 79                           Ekart Logistics    3.9    6.2k
# 213                        Cogent E Services    3.2    3.3k
# 261           Amazon Transportation Services    4.1    2.8k
# 287                       I Process Services    3.8    2.7k
# 317               TVS Supply Chain Solutions    3.8    2.4k
# ...                                      ...    ...     ...
# 9986                      Advics North India    4.0      96
# 9989                              BNB Groupe    3.1      96
# 9990                         Upland Software    4.7      96
# 9996  Kuwait Integrated Petroleum Industries    4.2      96
# 9997                          Civet Projects    4.2      97
#
#                category                        hq no_of_branches salary  \
# 79                  NaN     Bangalore / Bengaluru            705  14.7k
# 213                 NaN                     Noida             49   9.7k
# 261                 NaN  Hyderabad / Secunderabad            218   7.6k
# 287                 NaN                    Mumbai            372   5.2k
# 317                 NaN                   Chennai            145   8.2k
# ...                 ...                       ...            ...    ...
# 9986                NaN                    Rohtak              2    361
# 9989                NaN                 Ahmedabad              7    209
# 9990  Software Product      Bangalore / Bengaluru            NaN    141
# 9996                NaN                    Mumbai              8    469
# 9997                NaN  Hyderabad / Secunderabad             14    279
#
#      no_of_interviews jobs
# 79                360    1
# 213               269    1
# 261               238   --
# 287               118   --
# 317               141   14
# ...               ...  ...
# 9986                5   --
# 9989               10    1
# 9990               15    1
# 9996               16   --
# 9997                5    6
#
# [681 rows x 9 columns]

# %%
data_set.to_csv("companies.csv", index=False)
